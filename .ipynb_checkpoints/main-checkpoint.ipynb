# %%
import requests

# %%
import http.client

conn = http.client.HTTPSConnection("data.nayaone.com")
payload = ''
headers = {
  'Accept-Profile': 'api',
  'sandpit-key': 'n1p.A07Zvy7n.hU4xmAzFXha9WCDktW4rQMleiWs'
}
conn.request("GET", "/D04_fraud_events", payload, headers)
res = conn.getresponse()
data = res.read()
print(res.status, res.reason)
print(data.decode("utf-8"))
# Out:
# 404 Not Found
# {"message":"Not found"}
